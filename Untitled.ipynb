# %% [markdown]
# # Q-Learning Tic-Tac-Toe AI

# %%
import numpy as np
import random

# %%
board = np.array([['-','-','-'],['-','-','-'],['-','-','-']])
print(board)
# Out:
# [['-' '-' '-']
#  ['-' '-' '-']
#  ['-' '-' '-']]
